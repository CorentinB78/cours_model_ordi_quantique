# %%
import sys
sys.path.append('/usr/lib/python3/dist-packages')
import numpy as np

# %% [markdown]
# Quelques règles à respecter pour éviter les problèmes techniques:
# - Vous devez avoir installé "numpy" et utiliser python 3.
# - Écrivez votre code dans "my_emulator/".
# - N'écrivez rien dans "tools/", car il sera mis à jour au cours du semestre.

# %% [markdown]
# # States

# %%
from tools.display import print_state

nb_qubits = 3
state = np.zeros(2**nb_qubits, dtype=complex)
state[0] = 1. / np.sqrt(2.)
state[3] = 1. / np.sqrt(2.)

print("norm of state:", np.linalg.norm(state))

# %%
print_state(state)

# %% [markdown]
# # Gates

# %%
from tools.gates import GATES_1QB, GATES_2QB

print("### One qubit gates available: ###")
for key, val in GATES_1QB.items():
    print(key)
    print(val)

# %%
print("### Two qubit gates available: ###")
for key, val in GATES_2QB.items():
    print(key)
    print(val)

# %% [markdown]
# # Circuits

# %%
from tools.circuits import make_GHZ_circuit

circ_ghz = make_GHZ_circuit(4)

print(circ_ghz)

# %%
from tools.display import print_circuit

print_circuit(circ_ghz)

# %% [markdown]
# # Useful numpy functions

# %%
np.array

# %%
np.zeros

# %%
np.kron

# %%
np.eye

# %%
mat = np.array([[0., 1.], [2., 1.]])

mat @ mat
